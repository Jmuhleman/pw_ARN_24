# %% [markdown]
# # First experiment: awake / asleep

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import keras
from keras import layers
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
import random as random

trainset_1 = pd.read_csv('EEG_mouse_data_1.csv')
trainset_2 = pd.read_csv('EEG_mouse_data_2.csv')
testset_1 = pd.read_csv('EEG_mouse_data_test.csv')

# %%
# visualisation des données par classe
def show_boxplots(df):
    fig, axs = plt.subplots(20, 5, figsize=(25, 120))
    axs = axs.flatten()

    for i, col in enumerate(df.columns[1:]):
        sns.boxplot(x='state', y=col, data=df, ax=axs[i])
    
    fig.suptitle('Boxplot of the amplitudes', fontsize=14)
    fig.tight_layout(rect=[0, 0.03, 1, 0.98])

# %%
# normlisation des features
from sklearn.preprocessing import StandardScaler
import pandas as pd

def normalize(df):
    headers = df.columns
    scaler = StandardScaler()
    
    numerical_columns = df.select_dtypes(include=['int', 'float']).columns
    df[numerical_columns] = scaler.fit_transform(df[numerical_columns])
    normalized_data = pd.DataFrame(df, columns=headers[:-1])

    return normalized_data

# %%
# extraction des colonnes
# envisager de faire la séléction des features ici
def extract_features(data, n):
    return data.iloc[:,:n+1]

# %%
def create_model():
  # 2 inputs
  # 2 hidden nodes
  # 1 output

  mlp = keras.Sequential([
      layers.Input(shape=(25,)),
      layers.Dense(3, activation="tanh"), # Try different numbers of hidden neurons here (e.g. 2, 4, 8, 32, 128)
      layers.Dense(1, activation="tanh"),
  ])

  # Experiment with hyperparameters here:
  # momentum: [0, 0.8, 0.9, 0.99]
  # learning_rate: [0.1, 0.01, 0.001, 0.0001]
  mlp.compile(optimizer=keras.optimizers.SGD(learning_rate=0.01, momentum=0.99),loss="mse",)

  return mlp
mlp = create_model()
mlp.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 3)                   │              78 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 82 (328.00 B)
#  Trainable params: 82 (328.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import keras
from keras import layers
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
import random as random
# Programme principal de traitement du train set #1
normal_trainset_1 = extract_features(trainset_1, 26)
normal_trainset_1 = normalize(normal_trainset_1)
normal_trainset_1 = normal_trainset_1.sample(frac=1, random_state=42)

# splitting en 3 folds
keras.utils.set_random_seed(123)
kf = KFold(n_splits=3, shuffle=True)

y = normal_trainset_1['state'].map({'w': 1, 'r': 0, 'n': 0})
normal_trainset_1.drop(columns=['state'], inplace=True)
history_list = []
trained_mlp = []
for fold, (train_index, test_index) in enumerate(kf.split(normal_trainset_1)):
    
    model = create_model()
    
    history = model.fit(x=normal_trainset_1.iloc[train_index], y=y.iloc[train_index], 
                       validation_data=(normal_trainset_1.iloc[test_index], y.iloc[test_index]),
                       epochs=100)
    
    history_list.append(history)
    trained_mlp.append(model)
# Out:
# Epoch 1/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2346 - val_loss: 0.0992
# Epoch 2/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0966 - val_loss: 0.0810
# Epoch 3/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0833 - val_loss: 0.0773
# Epoch 4/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0811 - val_loss: 0.0756
# Epoch 5/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0790 - val_loss: 0.0738
# Epoch 6/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0781 - val_loss: 0.0735
# Epoch 7/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0780 - val_loss: 0.0732
# Epoch 8/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0778 - val_loss: 0.0729
# Epoch 9/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0782 - val_loss: 0.0725
# Epoch 10/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0781 - val_loss: 0.0763
# Epoch 11/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0773 - val_loss: 0.0767
# Epoch 12/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0777 - val_loss: 0.0754
# Epoch 13/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0758 - val_loss: 0.0758
# Epoch 14/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0757 - val_loss: 0.0760
# Epoch 15/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0758 - val_loss: 0.0759
# Epoch 16/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0757 - val_loss: 0.0748
# Epoch 17/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0751 - val_loss: 0.0740
# Epoch 18/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0748 - val_loss: 0.0737
# Epoch 19/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0744 - val_loss: 0.0735
# Epoch 20/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0740 - val_loss: 0.0732
# Epoch 21/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0737 - val_loss: 0.0730
# Epoch 22/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0735 - val_loss: 0.0729
# Epoch 23/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0733 - val_loss: 0.0728
# Epoch 24/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0732 - val_loss: 0.0727
# Epoch 25/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0731 - val_loss: 0.0727
# Epoch 26/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0731 - val_loss: 0.0727
# Epoch 27/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0730 - val_loss: 0.0727
# Epoch 28/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0730 - val_loss: 0.0727
# Epoch 29/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0730 - val_loss: 0.0727
# Epoch 30/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0729 - val_loss: 0.0727
# Epoch 31/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0729 - val_loss: 0.0727
# Epoch 32/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0729 - val_loss: 0.0727
# Epoch 33/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0728 - val_loss: 0.0727
# Epoch 34/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0728 - val_loss: 0.0727
# Epoch 35/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0727 - val_loss: 0.0727
# Epoch 36/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0727 - val_loss: 0.0728
# Epoch 37/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0727 - val_loss: 0.0728
# Epoch 38/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0727 - val_loss: 0.0728
# Epoch 39/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0727 - val_loss: 0.0728
# Epoch 40/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 41/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 42/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 43/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 44/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 45/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 46/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 47/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 48/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 49/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0725 - val_loss: 0.0729
# Epoch 50/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0725 - val_loss: 0.0729
# Epoch 51/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0725 - val_loss: 0.0729
# Epoch 52/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0725 - val_loss: 0.0729
# Epoch 53/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0725 - val_loss: 0.0729
# Epoch 54/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0725 - val_loss: 0.0729
# Epoch 55/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0725 - val_loss: 0.0728
# Epoch 56/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0725 - val_loss: 0.0728
# Epoch 57/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0725 - val_loss: 0.0728
# Epoch 58/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0725 - val_loss: 0.0728
# Epoch 59/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0725 - val_loss: 0.0728
# Epoch 60/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0725 - val_loss: 0.0728
# Epoch 61/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 62/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 63/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 64/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 65/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 66/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 67/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 68/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 69/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 70/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 71/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 72/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 73/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 74/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 75/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 76/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 77/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 78/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 79/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 80/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 81/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 82/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 83/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 84/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 85/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 86/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 87/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 88/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 89/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 90/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 91/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 92/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 93/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 94/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 95/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 96/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 97/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 98/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 99/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 100/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0729
# Epoch 1/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1973 - val_loss: 0.0848
# Epoch 2/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0799 - val_loss: 0.0795
# Epoch 3/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0747 - val_loss: 0.0789
# Epoch 4/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0731 - val_loss: 0.0744
# Epoch 5/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0715 - val_loss: 0.0728
# Epoch 6/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0711 - val_loss: 0.0727
# Epoch 7/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0705 - val_loss: 0.0728
# Epoch 8/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0701 - val_loss: 0.0728
# Epoch 9/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0698 - val_loss: 0.0728
# Epoch 10/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0695 - val_loss: 0.0728
# Epoch 11/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0693 - val_loss: 0.0727
# Epoch 12/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0691 - val_loss: 0.0728
# Epoch 13/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0690 - val_loss: 0.0728
# Epoch 14/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0689 - val_loss: 0.0729
# Epoch 15/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0689 - val_loss: 0.0729
# Epoch 16/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0689 - val_loss: 0.0730
# Epoch 17/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0689 - val_loss: 0.0730
# Epoch 18/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0689 - val_loss: 0.0730
# Epoch 19/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0690 - val_loss: 0.0730
# Epoch 20/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0690 - val_loss: 0.0731
# Epoch 21/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0690 - val_loss: 0.0731
# Epoch 22/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0691 - val_loss: 0.0731
# Epoch 23/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0691 - val_loss: 0.0732
# Epoch 24/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0692 - val_loss: 0.0732
# Epoch 25/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0692 - val_loss: 0.0732
# Epoch 26/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0693 - val_loss: 0.0733
# Epoch 27/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0694 - val_loss: 0.0733
# Epoch 28/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0694 - val_loss: 0.0733
# Epoch 29/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0695 - val_loss: 0.0733
# Epoch 30/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0696 - val_loss: 0.0734
# Epoch 31/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0697 - val_loss: 0.0734
# Epoch 32/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0698 - val_loss: 0.0735
# Epoch 33/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0700 - val_loss: 0.0736
# Epoch 34/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0701 - val_loss: 0.0738
# Epoch 35/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0703 - val_loss: 0.0742
# Epoch 36/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0706 - val_loss: 0.0753
# Epoch 37/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0711 - val_loss: 0.0777
# Epoch 38/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0718 - val_loss: 0.0824
# Epoch 39/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0731 - val_loss: 0.0864
# Epoch 40/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0742 - val_loss: 0.0849
# Epoch 41/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0733 - val_loss: 0.0837
# Epoch 42/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0831
# Epoch 43/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0723 - val_loss: 0.0830
# Epoch 44/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0723 - val_loss: 0.0828
# Epoch 45/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0722 - val_loss: 0.0825
# Epoch 46/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0719 - val_loss: 0.0820
# Epoch 47/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0716 - val_loss: 0.0815
# Epoch 48/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0713 - val_loss: 0.0809
# Epoch 49/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0711 - val_loss: 0.0802
# Epoch 50/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0708 - val_loss: 0.0795
# Epoch 51/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0706 - val_loss: 0.0790
# Epoch 52/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0704 - val_loss: 0.0786
# Epoch 53/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0703 - val_loss: 0.0783
# Epoch 54/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0782
# Epoch 55/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0782
# Epoch 56/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0783
# Epoch 57/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0784
# Epoch 58/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0785
# Epoch 59/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0787
# Epoch 60/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0788
# Epoch 61/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0789
# Epoch 62/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0790
# Epoch 63/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0792
# Epoch 64/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0793
# Epoch 65/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0795
# Epoch 66/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0797
# Epoch 67/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0798
# Epoch 68/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0799
# Epoch 69/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0703 - val_loss: 0.0800
# Epoch 70/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0703 - val_loss: 0.0801
# Epoch 71/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0703 - val_loss: 0.0802
# Epoch 72/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0703 - val_loss: 0.0802
# Epoch 73/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0703 - val_loss: 0.0802
# Epoch 74/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0703 - val_loss: 0.0803
# Epoch 75/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0803
# Epoch 76/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0803
# Epoch 77/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0802
# Epoch 78/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0802
# Epoch 79/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0802
# Epoch 80/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0802
# Epoch 81/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0801
# Epoch 82/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0801
# Epoch 83/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0701 - val_loss: 0.0801
# Epoch 84/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0701 - val_loss: 0.0800
# Epoch 85/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0701 - val_loss: 0.0800
# Epoch 86/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0701 - val_loss: 0.0800
# Epoch 87/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0701 - val_loss: 0.0799
# Epoch 88/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0701 - val_loss: 0.0799
# Epoch 89/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0701 - val_loss: 0.0799
# Epoch 90/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0701 - val_loss: 0.0798
# Epoch 91/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0700 - val_loss: 0.0798
# Epoch 92/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0700 - val_loss: 0.0797
# Epoch 93/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0700 - val_loss: 0.0797
# Epoch 94/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0700 - val_loss: 0.0796
# Epoch 95/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0700 - val_loss: 0.0795
# Epoch 96/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0700 - val_loss: 0.0795
# Epoch 97/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0699 - val_loss: 0.0794
# Epoch 98/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0699 - val_loss: 0.0793
# Epoch 99/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0699 - val_loss: 0.0792
# Epoch 100/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0699 - val_loss: 0.0791
# Epoch 1/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2445 - val_loss: 0.1142
# Epoch 2/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1066 - val_loss: 0.0974
# Epoch 3/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0932 - val_loss: 0.0908
# Epoch 4/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0819 - val_loss: 0.0855
# Epoch 5/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0800 - val_loss: 0.0840
# Epoch 6/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0789 - val_loss: 0.0836
# Epoch 7/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0784 - val_loss: 0.0840
# Epoch 8/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0783 - val_loss: 0.0843
# Epoch 9/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0781 - val_loss: 0.0845
# Epoch 10/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0778 - val_loss: 0.0844
# Epoch 11/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0773 - val_loss: 0.0846
# Epoch 12/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0770 - val_loss: 0.0839
# Epoch 13/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0766 - val_loss: 0.0826
# Epoch 14/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0758 - val_loss: 0.0814
# Epoch 15/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0753 - val_loss: 0.0806
# Epoch 16/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0751 - val_loss: 0.0801
# Epoch 17/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0750 - val_loss: 0.0798
# Epoch 18/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0750 - val_loss: 0.0795
# Epoch 19/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0751 - val_loss: 0.0792
# Epoch 20/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0752 - val_loss: 0.0789
# Epoch 21/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0755 - val_loss: 0.0787
# Epoch 22/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0758 - val_loss: 0.0785
# Epoch 23/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0760 - val_loss: 0.0783
# Epoch 24/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0761 - val_loss: 0.0781
# Epoch 25/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0761 - val_loss: 0.0779
# Epoch 26/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0762 - val_loss: 0.0779
# Epoch 27/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0763 - val_loss: 0.0779
# Epoch 28/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0763 - val_loss: 0.0778
# Epoch 29/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0763 - val_loss: 0.0778
# Epoch 30/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0762 - val_loss: 0.0777
# Epoch 31/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0761 - val_loss: 0.0776
# Epoch 32/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0759 - val_loss: 0.0776
# Epoch 33/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0758 - val_loss: 0.0776
# Epoch 34/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0758 - val_loss: 0.0778
# Epoch 35/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0759 - val_loss: 0.0778
# Epoch 36/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0761 - val_loss: 0.0778
# Epoch 37/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0762 - val_loss: 0.0780
# Epoch 38/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0762 - val_loss: 0.0780
# Epoch 39/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0762 - val_loss: 0.0781
# Epoch 40/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0763 - val_loss: 0.0782
# Epoch 41/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0764 - val_loss: 0.0781
# Epoch 42/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0766 - val_loss: 0.0779
# Epoch 43/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0767 - val_loss: 0.0777
# Epoch 44/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0766 - val_loss: 0.0776
# Epoch 45/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0764 - val_loss: 0.0771
# Epoch 46/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0764 - val_loss: 0.0772
# Epoch 47/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0760 - val_loss: 0.0770
# Epoch 48/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0760 - val_loss: 0.0771
# Epoch 49/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0758 - val_loss: 0.0768
# Epoch 50/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0758 - val_loss: 0.0770
# Epoch 51/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0757 - val_loss: 0.0767
# Epoch 52/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0758 - val_loss: 0.0767
# Epoch 53/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0757 - val_loss: 0.0765
# Epoch 54/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0758 - val_loss: 0.0764
# Epoch 55/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0753 - val_loss: 0.0762
# Epoch 56/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0750 - val_loss: 0.0761
# Epoch 57/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0742 - val_loss: 0.0759
# Epoch 58/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0739 - val_loss: 0.0760
# Epoch 59/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0734 - val_loss: 0.0759
# Epoch 60/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0732 - val_loss: 0.0761
# Epoch 61/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0729 - val_loss: 0.0759
# Epoch 62/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0729 - val_loss: 0.0761
# Epoch 63/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0727 - val_loss: 0.0760
# Epoch 64/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0727 - val_loss: 0.0762
# Epoch 65/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0726 - val_loss: 0.0762
# Epoch 66/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0723 - val_loss: 0.0763
# Epoch 67/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0724 - val_loss: 0.0762
# Epoch 68/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0722 - val_loss: 0.0763
# Epoch 69/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0723 - val_loss: 0.0763
# Epoch 70/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0720 - val_loss: 0.0762
# Epoch 71/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0722 - val_loss: 0.0761
# Epoch 72/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0719 - val_loss: 0.0761
# Epoch 73/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0721 - val_loss: 0.0761
# Epoch 74/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0719 - val_loss: 0.0761
# Epoch 75/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0720 - val_loss: 0.0762
# Epoch 76/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0719 - val_loss: 0.0762
# Epoch 77/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0720 - val_loss: 0.0762
# Epoch 78/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0719 - val_loss: 0.0762
# Epoch 79/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0721 - val_loss: 0.0762
# Epoch 80/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0719 - val_loss: 0.0763
# Epoch 81/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0721 - val_loss: 0.0763
# Epoch 82/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0718 - val_loss: 0.0764
# Epoch 83/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0720 - val_loss: 0.0765
# Epoch 84/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0718 - val_loss: 0.0765
# Epoch 85/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0720 - val_loss: 0.0766
# Epoch 86/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0718 - val_loss: 0.0767
# Epoch 87/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0719 - val_loss: 0.0767
# Epoch 88/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0717 - val_loss: 0.0768
# Epoch 89/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0719 - val_loss: 0.0768
# Epoch 90/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0717 - val_loss: 0.0769
# Epoch 91/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0719 - val_loss: 0.0769
# Epoch 92/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0716 - val_loss: 0.0769
# Epoch 93/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0718 - val_loss: 0.0769
# Epoch 94/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0716 - val_loss: 0.0769
# Epoch 95/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0718 - val_loss: 0.0769
# Epoch 96/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0716 - val_loss: 0.0769
# Epoch 97/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0718 - val_loss: 0.0769
# Epoch 98/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0716 - val_loss: 0.0769
# Epoch 99/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0717 - val_loss: 0.0770
# Epoch 100/100
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0715 - val_loss: 0.0770

# %%
import numpy as np
import matplotlib.pyplot as pl
train_losses = np.array([history.history['loss'] for history in history_list])
val_losses = np.array([history.history['val_loss'] for history in history_list])

# Calculate mean and standard deviation for training and validation losses
mean_train_loss = np.mean(train_losses, axis=0)
std_train_loss = np.std(train_losses, axis=0)
mean_val_loss = np.mean(val_losses, axis=0)
std_val_loss = np.std(val_losses, axis=0)

# Plot mean and standard deviation for training loss
pl.plot(mean_train_loss, label='Training Loss (Mean)')
pl.fill_between(range(len(mean_train_loss)), mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha=0.3, label='Training Loss (Std)')

# Plot mean and standard deviation for validation loss
pl.plot(mean_val_loss, label='Validation Loss (Mean)')
pl.fill_between(range(len(mean_val_loss)), mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.3, label='Validation Loss (Std)')

# Add labels and legend
pl.xlabel('Epochs')
pl.ylabel('Loss')
pl.legend()

# Display the plot
pl.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, f1_score
import seaborn as sns

def plot_confusion_matrix(confusion_matrix, title):
    # Plot confusion matrix
    pl.figure(figsize=(8, 6))
    sns.heatmap(confusion_matrix.astype(int), annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=["r/nr", "w"], yticklabels=["r/nr", "w"])
    pl.title(title)
    pl.xlabel('Predicted')
    pl.ylabel('True')
    pl.show()

f1_scores = []
mean_confusion_matrix = np.zeros((2, 2))

for i, (train_index, test_index) in enumerate(kf.split(normal_trainset_1)):
    # Evaluate the trained model on the test fold
    predictions = (trained_mlp[i].predict(normal_trainset_1.iloc[test_index]) > 0).astype(int)
    true_labels = (y.iloc[test_index] > 0).astype(int)

    # Compute confusion matrix
    cm = confusion_matrix(true_labels, predictions)
    mean_confusion_matrix += confusion_matrix(true_labels, predictions)

    # Compute confusion matrix and plot
    plot_confusion_matrix(cm, f'Confusion Matrix - Fold {i + 1}')

    # Compute F1 score
    f1 = f1_score(true_labels, predictions)
    f1_scores.append(f1)
    print(f"F1 Score - Fold {i + 1}: {f1}")

# Plot mean confusion matrix
plot_confusion_matrix(mean_confusion_matrix, 'Global confusion matrix')

# Calculate and display the mean F1 score across all folds
mean_f1_score = np.mean(f1_scores)
print(f"Mean F1 Score across all folds: {mean_f1_score}")
# Out:
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# F1 Score - Fold 1: 0.7409340915447002
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# F1 Score - Fold 2: 0.7548630957868535
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step
# F1 Score - Fold 3: 0.9044216167932112
# Mean F1 Score across all folds: 0.800072934708255
